# %% [markdown]
# # Training

# %% [markdown]
# Setting correct path to data files

# %%
import sys
import os
import yaml

# Dynamically locate the root directory
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(ROOT_DIR)

# Ensure correct path to config.yaml
CONFIG_PATH = os.path.join(ROOT_DIR, "config.yaml")
with open(CONFIG_PATH, "r") as file:
    config = yaml.safe_load(file)

# Ensure all data paths are absolute
config["data"]["train_imgs"] = os.path.join(ROOT_DIR, config["data"]["train_imgs"])
config["data"]["train_labels"] = os.path.join(ROOT_DIR, config["data"]["train_labels"])
config["data"]["test_imgs"] = os.path.join(ROOT_DIR, config["data"]["test_imgs"])
config["data"]["test_labels"] = os.path.join(ROOT_DIR, config["data"]["test_labels"])
config["model"]["path"] = os.path.join(ROOT_DIR, "models")

# %% [markdown]
# #### The following sections encapsulate loading, augmentation, training, and evaluation into a single structured pipeline for efficient experimentation.

# %% [markdown]
# ## v1

# %% [markdown]
# **Parameters:**
#
# - **learning rate: 0.0008**
# - **phase1 epochs: 10**
# - **phase2 epochs: 5**
# - **steps per epoch: 500**
# - **validation steps: 100**
# - **model name: mnist_v1.keras**

# %%
import main

config["training"]["learning_rate"] = 0.0008
config["training"]["phase1_epochs"] = 10
config["training"]["phase2_epochs"] = 5
config["training"]["steps_per_epoch"] = 500
config["training"]["validation_steps"] = 100
config["training"]["model_name"] = "mnist_v1.keras"

main.main(config)
# Out:
# 2025-01-20 10:03:02.668094: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 25ms/step - accuracy: 0.5442 - loss: 1.3115 - val_accuracy: 0.9135 - val_loss: 0.2867
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - accuracy: 0.8829 - loss: 0.3967 - val_accuracy: 0.9454 - val_loss: 0.1794
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 50s 27ms/step - accuracy: 0.9191 - loss: 0.2733 - val_accuracy: 0.9581 - val_loss: 0.1317
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9385 - loss: 0.2133 - val_accuracy: 0.9610 - val_loss: 0.1232
# Epoch 5/10
# ...

# %% [markdown]
# ## v2

# %% [markdown]
# **Parameters:**
#
# - **learning rate: 0.0008**
# - **phase1 epochs: 20**
# - **phase2 epochs: 10**
# - **steps per epoch: 500**
# - **validation steps: 100**
# - **model name: mnist_v2.keras**

# %%
import main

config["training"]["learning_rate"] = 0.0008
config["training"]["phase1_epochs"] = 20
config["training"]["phase2_epochs"] = 10
config["training"]["model_name"] = "mnist_v2.keras"

main.main(config)
# Out:
# Training
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - accuracy: 0.5431 - loss: 1.2993 - val_accuracy: 0.9094 - val_loss: 0.2876
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.8733 - loss: 0.4177 - val_accuracy: 0.9344 - val_loss: 0.1996
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.9157 - loss: 0.2877 - val_accuracy: 0.9536 - val_loss: 0.1502
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.9361 - loss: 0.2254 - val_accuracy: 0.9614 - val_loss: 0.1296
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.9485 - loss: 0.1837 - val_accuracy: 0.9620 - val_loss: 0.1207
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.9542 - loss: 0.1686 - val_accuracy: 0.9744 - val_loss: 0.0822
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 23ms/step - accuracy: 0.9602 - loss: 0.1438 - val_accuracy: 0.9723 - val_loss: 0.0887
# Epoch 8/20
# ...

# %% [markdown]
# ## v3

# %% [markdown]
# **Parameters:**
#
# - **learning rate: 0.0008**
# - **phase1 epochs: 30**
# - **phase2 epochs: 20**
# - **steps per epoch: 500**
# - **validation steps: 100**
# - **model name: mnist_v2.keras**

# %%
import main

config["training"]["learning_rate"] = 0.0008
config["training"]["phase1_epochs"] = 30
config["training"]["phase2_epochs"] = 20
config["training"]["model_name"] = "mnist_v3.keras"

main.main(config)
# Out:
# Training
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - accuracy: 0.5223 - loss: 1.3708 - val_accuracy: 0.9127 - val_loss: 0.2854
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.8673 - loss: 0.4378 - val_accuracy: 0.9400 - val_loss: 0.1935
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 25ms/step - accuracy: 0.9146 - loss: 0.2989 - val_accuracy: 0.9559 - val_loss: 0.1379
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 23ms/step - accuracy: 0.9332 - loss: 0.2363 - val_accuracy: 0.9602 - val_loss: 0.1303
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.9444 - loss: 0.1979 - val_accuracy: 0.9637 - val_loss: 0.1137
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9513 - loss: 0.1707 - val_accuracy: 0.9688 - val_loss: 0.1020
# Epoch 7/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.9571 - loss: 0.1554 - val_accuracy: 0.9736 - val_loss: 0.0826
# Epoch 8/30
# ...

# %% [markdown]
# ## v4

# %% [markdown]
# **Parameters:**
#
# - **learning rate: 0.0006**
# - **phase1 epochs: 35**
# - **phase2 epochs: 25**
# - **steps per epoch: 500**
# - **validation steps: 100**
# - **model name: mnist_v2.keras**

# %%
import main

config["training"]["learning_rate"] = 0.0006  # Slightly lower LR to stabilize training
config["training"]["phase1_epochs"] = 35  # Increase phase 1 for better feature extraction
config["training"]["phase2_epochs"] = 25  # Increase phase 2 for better fine-tuning
config["training"]["model_name"] = "mnist_v4.keras"

main.main(config)
# Out:
# Training
# Epoch 1/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - accuracy: 0.5038 - loss: 1.4117 - val_accuracy: 0.8740 - val_loss: 0.4012
# Epoch 2/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.8566 - loss: 0.4701 - val_accuracy: 0.9374 - val_loss: 0.2053
# Epoch 3/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.8977 - loss: 0.3468 - val_accuracy: 0.9477 - val_loss: 0.1697
# Epoch 4/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9240 - loss: 0.2621 - val_accuracy: 0.9518 - val_loss: 0.1482
# Epoch 5/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9357 - loss: 0.2288 - val_accuracy: 0.9602 - val_loss: 0.1356
# Epoch 6/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.9444 - loss: 0.1972 - val_accuracy: 0.9640 - val_loss: 0.1108
# Epoch 7/35
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9517 - loss: 0.1743 - val_accuracy: 0.9627 - val_loss: 0.1181
# Epoch 8/35
# ...

# %% [markdown]
# Testing different augmentation on the best performant model v3

# %% [markdown]
# ## v4

# %%
config["training"]["learning_rate"] = 0.0008
config["training"]["phase1_epochs"] = 30
config["training"]["phase2_epochs"] = 20
config["training"]["model_name"] = "mnist_v4.keras"

config["augmentation"]["rotation"] = 10 # 50% reduced


main.main(config)
# Out:
# Training
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 16ms/step - accuracy: 0.5822 - loss: 1.2009 - val_accuracy: 0.9343 - val_loss: 0.2159
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 17ms/step - accuracy: 0.9063 - loss: 0.3190 - val_accuracy: 0.9586 - val_loss: 0.1354
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.9411 - loss: 0.2099 - val_accuracy: 0.9686 - val_loss: 0.0997
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.9530 - loss: 0.1679 - val_accuracy: 0.9701 - val_loss: 0.0939
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 34s 18ms/step - accuracy: 0.9598 - loss: 0.1467 - val_accuracy: 0.9781 - val_loss: 0.0722
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9642 - loss: 0.1276 - val_accuracy: 0.9741 - val_loss: 0.0852
# Epoch 7/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 34s 18ms/step - accuracy: 0.9685 - loss: 0.1133 - val_accuracy: 0.9777 - val_loss: 0.0689
# Epoch 8/30
# ...
